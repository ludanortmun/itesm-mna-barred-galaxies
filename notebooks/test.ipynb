# %%
from collections import OrderedDict

import torch

from bargal.classifier import GalaxyClassifier
from bargal.images.client import GalaxyImageClient
from bargal.preprocessing import GRLOG_GR_DIFF
from bargal.dataset.load import load_dataset

# %%
state_dict = torch.load('../models/model.pth', weights_only=True, map_location='cpu')
img_client = GalaxyImageClient(storage_path=r'D:\datasets\bargal\images')

# %%
n_state_dict = OrderedDict()

for (k, v) in state_dict.items():
    n_state_dict[k[10:]]=v

# %%
classifier = GalaxyClassifier(img_client=img_client, state_dict=n_state_dict, img_preprocessor=GRLOG_GR_DIFF)

# %%
df = load_dataset('../data/dataset.csv')

# %%
def get_random_galaxy(label=None):
    if label is None:
        return df.sample(1).to_dict(orient='records')[0]

    return df[df.Bars == label].sample(1).to_dict(orient='records')[0]

# %%
barred = df[df['Bars'] == 1].reset_index(drop=True)

barred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1345 entries, 0 to 1344
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    1345 non-null   object
#  1   objra   1345 non-null   float64
#  2   objdec  1345 non-null   float64
#  3   Bars    1345 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 42.2+ KB

# %%
for i in range(len(barred)):
    g = barred.iloc[i].to_dict()
    print(classifier.classify(g))
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[124], line 3
#       1 for i in range(len(barred)):
#       2     g = barred.iloc[i].to_dict()
# ----> 3     print(classifier.classify(g))
#
# File ~\repos\tec\itesm-mna-barred-galaxies\bargal\classifier.py:39, in GalaxyClassifier.classify(self, galaxy)
#      38 def classify(self, galaxy: Union[Galaxy, GalaxyDict]) -> bool:
# ---> 39     observation = self.img_client.get_as_observation(galaxy, use_fits=True, skip_rgb=True)
#      40     processed = self.img_preprocessor.preprocess(observation)
#      41     processed = (processed * 255).astype(np.uint8)
#
# File ~\repos\tec\itesm-mna-barred-galaxies\bargal\images\client.py:169, in GalaxyImageClient.get_as_observation(self, galaxy, save_to_disk, use_fits, skip_rgb)
#     166 # Otherwise, we download the FITS image for the galaxy.
#     167 # A benefit of this is that a single download will contain all three bands as separate channels.
#     168 fits_img_name = f"{g.name}.fits"
# --> 169 fits_data = self._get_cached(fits_img_name)
#     170 if not fits_data:
#     171     fits_data = _download_image(g, bands='grz', img_format='fits')
#
# File ~\repos\tec\itesm-mna-barred-galaxies\bargal\images\client.py:57, in GalaxyImageClient._get_cached(self, name)
#      54 def _get_cached(self, name: str) -> Optional[bytes]:
#      55     # Try disk cache if available
#      56     if self._diskcache and self._diskcache.has_image(name):
# ---> 57         image = self._diskcache.load_image(name)
#      58         return image
#      60     return None
#
# File ~\repos\tec\itesm-mna-barred-galaxies\bargal\images\storage.py:29, in ImageFileStore.load_image(self, image_name)
#      27 file_path = self.storage_path / image_name
#      28 with open(file_path, "rb") as image_file:
# ---> 29     return image_file.read()
#
# KeyboardInterrupt:
